# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:mysql@localhost/test

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('demo',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use demo;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('classroom',), ('same',), ('sample',), ('test',), ('xyz',)]

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90)]

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [(1, 'STU-E', 77, 'B'),
#  (1, 'STU-E', 76, 'B'),
#  (1, 'STU-A', 99, 'S'),
#  (2, 'STU-B', 98, 'S'),
#  (3, 'STU-C', 87, 'A'),
#  (4, 'STU-D', 86, 'A'),
#  (5, 'STU-E', 75, 'B')]

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 0), (2, 'b', 100000, 0), (3, 'c', None, 0)]

# %%
# %%sql
# select count(*) from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(7,)]

# %%
# %%sql
# select count(*) from xyz where networth>1000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(2,)]

# %%
# %%sql
# select count(networth) from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(2,)]

# %%
# %%sql
# select min(networth) from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(50000,)]

# %%
# %%sql
# select max(networth) from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(100000,)]

# %%
# %%sql
# alter table xyz add working varchar(5);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select * from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 0, None), (2, 'b', 100000, 0, None), (3, 'c', None, 0, None)]

# %%
# %%sql
# update xyz set networth=0 where sno=3;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', 0, 500, 'in')]

# %%
# %%sql
# select count(*) from xyz where working in('in','out');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(3,)]

# %%
# %%sql
# select * from xyz where working in('in');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 'a', 50000, 1000, 'in'), (3, 'c', 0, 500, 'in')]

# %%
# %%sql
# select * from xyz where working not in('in');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(2, 'b', 100000, 5000, 'out')]

# %%
# %%sql
# select * from xyz where working='in' and salary>100;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 'a', 50000, 1000, 'in'), (3, 'c', 0, 500, 'in')]

# %%
# %%sql
# select * from xyz where working='in' or salary>750;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', 0, 500, 'in')]

# %%
# %%sql
# select sum(salary) from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(Decimal('6500'),)]

# %%
# %%sql
# select count(*) as 'total no of record' from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(3,)]

# %%
# %%sql
# select sum(salary) as total from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(Decimal('6500'),)]

# %%
# %%sql
# select * from xyz where salary=(select max(salary) from xyz);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(2, 'b', 100000, 5000, 'out')]

# %%
# %%sql
# select * from xyz where salary=(select avg(salary) from xyz);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select avg(salary) from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(Decimal('2166.6667'),)]

# %%
# %%sql
# select * from xyz limit 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(1, 'a', 50000, 1000, 'in')]

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('classroom',), ('same',), ('sample',), ('test',), ('xyz',)]

# %%
# %%sql
# select * from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', 0, 500, 'in')]

# %%
# %%sql
# update xyz set networth=NULL where sno=3
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', None, 500, 'in')]

# %%
# %%sql
# insert into xyz values(4, NULL ,75000,2000,'out')
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', None, 500, 'in'),
#  (4, None, 75000, 2000, 'out')]

# %%
# %%sql
# select count(*) from xyz where name is null
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(1,)]

# %%
# %%sql
# select * from xyz where name is null
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(4, None, 75000, 2000, 'out')]

# %%
# %%sql
# select * from xyz where name is not null
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', None, 500, 'in')]

# %%
# %%sql
# insert into xyz values(5,'null',99999,1500,'out')
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from xyz where name is null or name='null'
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(5, 'null', 99999, 1500, 'out'), (4, None, 75000, 2000, 'out')]

# %%
# %%sql
# select * from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', None, 500, 'in'),
#  (4, None, 75000, 2000, 'out'),
#  (5, 'null', 99999, 1500, 'out')]

# %%
# %%sql
# select * from xyz where * is null
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '* is null' at line 1
# [SQL: select * from xyz where * is null]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select coalesce(name ,'d') from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('d',), ('a',), ('b',), ('c',), ('null',)]

# %%
# %%sql
# select * from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', None, 500, 'in'),
#  (4, None, 75000, 2000, 'out'),
#  (5, 'null', 99999, 1500, 'out')]

# %%
# %%sql
# select IFNULL(NAME,'D') from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('D',), ('a',), ('b',), ('c',), ('null',)]

# %%
# %%sql
# select * from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1, 'a', 50000, 1000, 'in'),
#  (2, 'b', 100000, 5000, 'out'),
#  (3, 'c', None, 500, 'in'),
#  (4, None, 75000, 2000, 'out'),
#  (5, 'null', 99999, 1500, 'out')]

# %%
# %%sql
# select * from sample
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90)]

# %%
# %%sql
# select upper(name) from sample
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('YASHU',), ('GOPAL',)]

# %%
# %%sql
# select lower(name) from sample
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('yashu',), ('gopal',)]

# %%
# %%sql
# select name,length(name) from sample
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('Yashu', 5), ('gopal', 5)]

# %%
# %%sql
# select concat(name,working) from xyz
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('ain',), ('bout',), ('cin',), (None,), ('nullout',)]

# %%
# %%sql
# select * from test
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [(1, 'STU-E', 77, 'B'),
#  (1, 'STU-E', 76, 'B'),
#  (1, 'STU-A', 99, 'S'),
#  (2, 'STU-B', 98, 'S'),
#  (3, 'STU-C', 87, 'A'),
#  (4, 'STU-D', 86, 'A'),
#  (5, 'STU-E', 75, 'B')]

# %%
# %%sql
# select substring(name,1,3) from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('STU',), ('STU',), ('STU',), ('STU',), ('STU',), ('STU',), ('STU',)]

# %%
# %%sql
# select substring(name,4,7) from test
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('-E',), ('-E',), ('-A',), ('-B',), ('-C',), ('-D',), ('-E',)]

# %%
# %%sql
# select * from sample
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90)]

# %%
# %%sql
# insert into sample values(103,'   pad   ',97);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90), (103, '   pad   ', 97)]

# %%
# %%sql
# select rpad(name,6,'*') from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Yashu*',), ('gopal*',), ('   pad',)]

# %%
# %%sql
# select replace(name,'gopal','Gopal') from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Yashu',), ('Gopal',), ('   pad   ',)]

# %%
# %%sql
# select instr(name,'a') from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(2,), (4,), (5,)]

# %%
# %%sql
# select left(name,1) from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Y',), ('g',), (' ',)]

# %%
# %%sql
# select right(name,1) from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('u',), ('l',), (' ',)]

# %%
# %%sql
# select reverse(name) as reversed from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('uhsaY',), ('lapog',), ('   dap   ',)]
