# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:mysql@localhost/test

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# create database demo;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('demo',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use demo;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table classroom(name varchar(100),regno int);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [('classroom',)]

# %%
# %%sql
# insert into classroom values('yashu',101);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from classroom
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [('yashu', 101)]

# %%
# %%sql
# select regno from classroom;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(101,)]

# %%
# %%sql
# insert into classroom values('yashu',101),('gopal',102),('naga arjuna',103);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from classroom;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('yashu', 101), ('yashu', 101), ('gopal', 102), ('naga arjuna', 103)]

# %%
# %%sql
# update classroom set name='vijay' where regno=101;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# select * from classroom;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('vijay', 101), ('vijay', 101), ('gopal', 102), ('naga arjuna', 103)]
