# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:mysql@localhost/test

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('demo',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use demo;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('classroom',), ('same',), ('sample',), ('test',), ('xyz',)]

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90)]

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('sno', 'int', 'YES', '', None, ''),
#  ('name', 'varchar(50)', 'YES', '', None, '')]

# %%
# %%sql
# alter table test add graded varchar(5);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('sno', 'int', 'YES', '', None, ''),
#  ('name', 'varchar(50)', 'YES', '', None, ''),
#  ('marks', 'int', 'YES', '', None, ''),
#  ('graded', 'varchar(5)', 'YES', '', None, '')]

# %%
# %%sql
# insert into test values(1,'STU-A',99,'S'),(1,'STU-B',98,'S'),(1,'STU-C',87,'A'),(1,'STU-D',86,'A'),(1,'STU-E',77,'B');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1, 'STU-A', 99, 'S'),
#  (1, 'STU-B', 98, 'S'),
#  (1, 'STU-C', 87, 'A'),
#  (1, 'STU-D', 86, 'A'),
#  (1, 'STU-E', 77, 'B')]

# %%
# %%sql
# select * from test where marks>80;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [(1, 'STU-A', 99, 'S'),
#  (1, 'STU-B', 98, 'S'),
#  (1, 'STU-C', 87, 'A'),
#  (1, 'STU-D', 86, 'A')]

# %%
# %%sql
# delete from test where marks>80;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(1, 'STU-E', 77, 'B')]

# %%
# %%sql
# insert into test values(1,'STU-A',99,'S'),(1,'STU-B',98,'S'),(1,'STU-C',87,'A'),(1,'STU-D',86,'A'),(1,'STU-E',76,'F');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 'STU-E', 77, 'B'), (1, 'STU-E', 76, 'F')]

# %%
# %%sql
# update test set graded='B' where marks=76;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 'STU-E', 77, 'B'), (1, 'STU-E', 76, 'B')]

# %%
# %%sql
# insert into test values(1,'STU-A',99,'S'),(2,'STU-B',98,'S'),(3,'STU-C',87,'A'),(4,'STU-D',86,'A'),(5,'STU-E',75,'B');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# []

# %%
# %%sql
# select * from test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [(1, 'STU-E', 77, 'B'),
#  (1, 'STU-E', 76, 'B'),
#  (1, 'STU-A', 99, 'S'),
#  (2, 'STU-B', 98, 'S'),
#  (3, 'STU-C', 87, 'A'),
#  (4, 'STU-D', 86, 'A'),
#  (5, 'STU-E', 75, 'B')]

# %%
# %%sql
# select * from test order by marks asc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [(5, 'STU-E', 75, 'B'),
#  (1, 'STU-E', 76, 'B'),
#  (1, 'STU-E', 77, 'B'),
#  (4, 'STU-D', 86, 'A'),
#  (3, 'STU-C', 87, 'A'),
#  (2, 'STU-B', 98, 'S'),
#  (1, 'STU-A', 99, 'S')]

# %%
# %%sql
# select * from test order by marks desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [(1, 'STU-A', 99, 'S'),
#  (2, 'STU-B', 98, 'S'),
#  (3, 'STU-C', 87, 'A'),
#  (4, 'STU-D', 86, 'A'),
#  (1, 'STU-E', 77, 'B'),
#  (1, 'STU-E', 76, 'B'),
#  (5, 'STU-E', 75, 'B')]

# %%
# %%sql
# select * from test where sno=1 and marks<90;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 'STU-E', 77, 'B'), (1, 'STU-E', 76, 'B')]

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('classroom',), ('same',), ('sample',), ('test',), ('xyz',)]

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu'), (102, 'gopal')]

# %%
# %%sql
# drop table xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table xyz(sno int primary key,name varchar(50) unique,networth int);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# insert into xyz values(1,'a',50000),(2,'b',100000),(3,'c',Null);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000), (2, 'b', 100000), (3, 'c', None)]

# %%
# %%sql
# alter table xyz add salary int not null;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 0), (2, 'b', 100000, 0), (3, 'c', None, 0)]

# %%
# %%sql
# desc xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('sno', 'int', 'NO', 'PRI', None, ''),
#  ('name', 'varchar(50)', 'YES', 'UNI', None, ''),
#  ('networth', 'int', 'YES', '', None, ''),
#  ('salary', 'int', 'NO', '', None, '')]

# %%
# %%sql
# insert into xyz values(4,'d',60000,null);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.IntegrityError) 1048 (23000): Column 'salary' cannot be null
# [SQL: insert into xyz values(4,'d',60000,null);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# insert into xyz values(3,'d',60000,200000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '3' for key 'xyz.PRIMARY'
# [SQL: insert into xyz values(3,'d',60000,200000);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from xyz;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'a', 50000, 0), (2, 'b', 100000, 0), (3, 'c', None, 0)]
