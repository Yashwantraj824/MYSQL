# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:mysql@localhost/test

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('demo',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use demo;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('classroom',), ('test',)]

# %%
# %%sql
# create table sample(sno int,name varchar(50),PRIMARY KEY(sno));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# insert into sample values(101,'yashu'),(102,'gopal'),(103,'naga arjun');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(101, 'yashu'), (102, 'gopal'), (103, 'naga arjun')]

# %%
# %%sql
# update sample set name='Yashu' WHERE name='yashu';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(101, 'Yashu'), (102, 'gopal'), (103, 'naga arjun')]

# %%
# %%sql
# delete from sample where sno=103;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu'), (102, 'gopal')]

# %%
# %%sql
# create table deletes(sno int);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# insert into deletes values(1),(2),(3),(4),(5);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# []

# %%
# %%sql
# select * from deletes;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1,), (2,), (3,), (4,), (5,)]

# %%
# %%sql
# truncate table deletes;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# drop table deletes;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create temporary table abc(regno int,name varchar(50));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table xyz select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# drop table abc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('classroom',), ('sample',), ('test',), ('xyz',)]

# %%
# %%sql
# create table same select sno from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# select * from same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101,), (102,)]

# %%
# %%sql
# drop table same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table same select sno from sample where sno<1000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# select * from same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101,), (102,)]

# %%
# %%sql
# drop table same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table same(sno int);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# insert into same select sno from sample where sno<1000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# select * from same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101,), (102,)]

# %%
# %%sql
# desc same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [('sno', 'int', 'YES', '', None, '')]

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu'), (102, 'gopal')]

# %%
# %%sql
# alter table sample add grade int;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', None), (102, 'gopal', None)]

# %%
# %%sql
# update sample set grade=90 where sno=102;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90)]

# %%
# %%sql
# desc same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('sno', 'int', 'YES', '', None, ''), ('grade', 'int', 'YES', '', None, '')]

# %%
# %%sql
# alter table same drop column grade;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc same;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [('sno', 'int', 'YES', '', None, '')]

# %%
# %%sql
# select * from sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'Yashu', 98), (102, 'gopal', 90)]

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('classroom',), ('same',), ('sample',), ('test',), ('xyz',)]

# %%
# %%sql
# alter table sample rename to demo;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('classroom',), ('demo',), ('same',), ('test',), ('xyz',)]

# %%
# %%sql
# alter table demo rename to sample;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []
