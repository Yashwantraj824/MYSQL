# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:mysql@localhost/test

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('demo',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use demo
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show tABLES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 9 rows affected.
# [('classroom',),
#  ('courses',),
#  ('customer',),
#  ('orders',),
#  ('same',),
#  ('sample',),
#  ('students',),
#  ('test',),
#  ('xyz',)]

# %%
# %%sql
# SELECT * FROM CLASSROOM;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('vijay', 101), ('vijay', 101), ('gopal', 102), ('naga arjuna', 103)]

# %%
# %%sql
# drop table classroom;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1051 (42S02): Unknown table 'demo.classroom'
# [SQL: drop table classroom;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# create table abc(transcation int,
#                  store varchar(2),
#                  salesamount int);
# insert into abc values(1,'A',100),(2,'B',300),(3,'A',150),(4,'B',300),(5,'A',200);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# 5 rows affected.
# []

# %%
# %%sql
# SELECT * FROM ABC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1, 'A', 100), (2, 'B', 300), (3, 'A', 150), (4, 'B', 300), (5, 'A', 200)]

# %%
# %%sql
# select sum(salesamount) from abc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(Decimal('1050'),)]

# %%
# %%sql
# select store,salesamount,sum(salesamount) over (partition by store order by transcation) as sum from abc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [('A', 100, Decimal('100')),
#  ('A', 150, Decimal('250')),
#  ('A', 200, Decimal('450')),
#  ('B', 300, Decimal('300')),
#  ('B', 300, Decimal('600'))]

# %%
# %%sql
# select store,sum(salesamount) from abc group by store;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('A', Decimal('450')), ('B', Decimal('600'))]
